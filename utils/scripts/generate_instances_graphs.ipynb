# %%
import os
import sys
sys.path.append('./../../')
from instance import Instance

# %%
path_root = './../../'
path_instances = path_root + 'instances/'
path_results = path_root + 'results/'
path_results_graphs = path_results + 'graphs/'
paths = [path_instances, path_results, path_results_graphs]

# %%
all_instances = [Instance.from_json(path_instances, file.split('.')[0]) for file in os.listdir(path_instances)]

# %%
for p in paths:
    if not os.path.exists(p):
        os.mkdir(p)

# %%
for i in all_instances:
    i.plot_dep_graph(path_results_graphs)
